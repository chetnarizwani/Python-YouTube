# %%
import numpy as np
import seaborn as sns

# %%
values = np.random.normal(70,3,100000)

# %%
values
# Out:
# array([66.85716533, 69.02627391, 73.35242668, ..., 73.77506732,
#        69.7228527 , 67.08233439])

# %%
sns.distplot(values,kde=True)
